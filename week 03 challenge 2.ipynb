# %%
students_id = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
18421131,
18421132,
18421133,
18421134,
18421135,
18421136,
18421137,
18421138,
18421139,
18421140,
18421141,
18421142,
18421143,
18421144,
18421145,
18421146,
18421147,
18421148,
18421149,
18421150,
18421151,
18421152,
18421153,
18421154,
18421155,
18421156,
18421157,
18421158,
18421159,
18421160
]
import random
random.shuffle(students_id)

case_list = [
'case1-build a calculator to evaluate your business model',
'case2-build a automatic earthquake robot to broadcast the new earthquake',
'case3-evaluate social media performance of a luxury brand',
'case4-study movie blockbuster \'Dying to Survive\'',
'case5-invest your money like the Internet giant, Tencent',
'case6-where are the 200,000 inferior vaccines flowing?',
'case7-study classics, who control the discourse power in \'Dream of the Red Chamber\'?',
'case8-research about Didi-driver crimes in China',
'case9-\'Me too\'analysis',
'case10-What is hip-hop in china?'
]
random.shuffle(case_list)

i = 0
for i in range(0, 10):
    print("group {}:".format(i+1))
    print('students_list {}:'.format(students_id[i*5]))
    print('students_list {}:'.format(students_id[i*5+1]))
    print('students_list {}:'.format(students_id[i*5+2]))
    print('students_list {}:'.format(students_id[i*5+3]))
    print('students_list {}:'.format(students_id[i*5+4]))
    print('assigned_case: {}'.format(case_list[i]))
    print("======================")
# Out:
# group 1:
# students_list 18421124:
# students_list 18421118:
# students_list 18421151:
# students_list 18421127:
# students_list 18421144:
# assigned_case: case9-'Me too'analysis
# ======================
# group 2:
# students_list 18421141:
# students_list 18421156:
# students_list 18421160:
# students_list 18421140:
# students_list 18421125:
# assigned_case: case3-evaluate social media performance of a luxury brand
# ======================
# group 3:
# students_list 18421139:
# students_list 18421123:
# students_list 18421115:
# students_list 18421159:
# students_list 18421150:
# assigned_case: case7-study classics, who control the discourse power in 'Dream of the Red Chamber'?
# ======================
# group 4:
# students_list 18421120:
# students_list 18421146:
# students_list 18421116:
# students_list 18421134:
# students_list 18421149:
# assigned_case: case2-build a automatic earthquake robot to broadcast the new earthquake
# ======================
# group 5:
# students_list 18421143:
# students_list 18421132:
# students_list 18421128:
# students_list 18421131:
# students_list 18421147:
# assigned_case: case4-study movie blockbuster 'Dying to Survive'
# ======================
# group 6:
# students_list 18421114:
# students_list 18421119:
# students_list 18421152:
# students_list 18421157:
# students_list 18421113:
# assigned_case: case1-build a calculator to evaluate your business model
# ======================
# group 7:
# students_list 18421137:
# students_list 18421135:
# students_list 18421153:
# students_list 18421121:
# students_list 18421155:
# assigned_case: case10-What is hip-hop in china?
# ======================
# group 8:
# students_list 18421130:
# students_list 18421154:
# students_list 18421111:
# students_list 18421145:
# students_list 18421136:
# assigned_case: case8-research about Didi-driver crimes in China
# ======================
# group 9:
# students_list 18421112:
# students_list 18421117:
# students_list 18421138:
# students_list 18421133:
# students_list 18421142:
# assigned_case: case6-where are the 200,000 inferior vaccines flowing?
# ======================
# group 10:
# students_list 18421158:
# students_list 18421122:
# students_list 18421148:
# students_list 18421126:
# students_list 18421129:
# assigned_case: case5-invest your money like the Internet giant, Tencent
# ======================
